# %% [markdown]
# ![python-logo.jpg](attachment:python-logo.jpg)

# %% [markdown]
# # Python Basic Day 2

# %% [markdown]
# # string

# %% [markdown]
# ### string can be indicated by double quote or single quote.

# %%
s = "ineuron"

# %%
type(s)
# Out:
# str

# %% [markdown]
# ### string indexing

# %%
s[0]
# Out:
# 'i'

# %%
s[5]
# Out:
# 'o'

# %% [markdown]
# ### string can be moved forward indexing or backward indexing.

# %%
s[-1]
# Out:
# 'n'

# %%
s[-2]
# Out:
# 'o'

# %%
s1 = "ineuron.ai"

# %%
type(s)
# Out:
# str

# %%
"this is my very first class on data science"
# Out:
# 'this is my very first class on data science'

# %%
'this is my very first class on data science class's
# Out:
#   File "C:\Users\nilut\AppData\Local\Temp/ipykernel_26496/2816309339.py", line 1
#     'this is my very first class on data science class's
#                                                        ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### here the python is not able to identify which single quote is at the end of the line, <br> whether single quote after the class is end point or not.

# %% [markdown]
# ### if you are using single-quote or double quote, then use it entirely on the sentence.<br> but if you have to use of single quote in between the sentences which is using single quote on entire sentence<br> then use double quote for enclosing entire sentences.

# %% [markdown]
# ### so correcting the previous code.

# %%
s2 = "this is my very first class on data science class's"

# %% [markdown]
# ### here in the below code, double quotes are there and words using single quote are also there.

# %%
s2
# Out:
# "this is my very first class on data science class's"

# %%
s2[8]
# Out:
# 'm'

# %% [markdown]
# ## string slicing

# %%
s2[1:5]
# Out:
# 'his '

# %% [markdown]
# ### here in the above code, string will run from 1 and go till 5 but it will count the steps of 0 to 4 excluding 5th one.

# %% [markdown]
# ### forward string slicing

# %%
s2[0:5]
# Out:
# 'this '

# %% [markdown]
# ### string slicing with jump of 2

# %%
s2[1:30:2]
# Out:
# 'hsi yvr is ls n'

# %%
 s3 = "nilutpal das"

# %% [markdown]
# ### string slicing with jump of 1

# %%
s3[0:12:1]
# Out:
# 'nilutpal das'

# %%
s3[0:12:2]
# Out:
# 'nlta a'

# %% [markdown]
# ### string slicing with jump of -1

# %%
s3[0:12:-1]
# Out:
# ''

# %% [markdown]
# ### why there is empty string?<br>
# ### Reason of output - string "nilutpal das" indexing starts from n = 0 go till 12 i.e. forward direction.<br> But the jump of -1 starts from  s = -1 to n = 0 which is i.e. backward direction.<br> indexing goes from forward to backward and jump goes from backward to forward that is why it get contradicted so no output.

# %%
s3[-1]
# Out:
# 's'

# %% [markdown]
# ### reverse of a string, here string starts from 12 i.e. s and go till n.

# %%
s3[12:0:-1]
# Out:
# 'sad laptuli'

# %% [markdown]
# ### 1. starting point is 12.<br> 2. end point is 0.<br> 3. jump step is -1.<br>
# ### reason of output - indexing starts from 12 and go to 0 i.e. from s of das and go till n of nilutpal.(going backward)<br> the jump is also backward -1 i.e. from s to n. this is why it is not giving empty string.

# %%
s3[12:0:-1]
# Out:
# 'sad laptuli'

# %% [markdown]
# ### from above code,you can see that we are expecting to get the result as "sad laptulin"?<br> we didn't get the last character "n". why???<br> because indexing starts from 12 it will go till last point i.e. 0 but excluding the last point 0.

# %%
s3[12:0:-2]
# Out:
# 'sdlpui'

# %% [markdown]
# ### above code the jump is taken by 2 step but as it is going from backward that is why the step for jump is also taken backward -2.

# %% [markdown]
# ### in the below code without giving starting point we have assigned the end point i.e. -3 still we get the output. how??

# %%
s3[:-3]
# Out:
# 'nilutpal '

# %% [markdown]
# ### 1. starting point and jump step is not assigned.<br> 2. starting point as default 0.<br> 3. jump step as default +1.<br> 4. end point is assigned as -3.
# ### reason it get output - according to the string 'nilutpal das', it will start from 0 and go till end i.e. 12 but when it will reach 10 because from backward -3 is equal to 10. as we have assigned -3 as end point it will stop there but while counting -3 will be excluded.

# %%
# point for reference
s3[0:12:1]
# Out:
# 'nilutpal das'

# %%
s3[-2:]
# Out:
# 'as'

# %% [markdown]
# ### 1. starting point is taken as -2.<br> 2. no end point and no jump step.<br> 3. end point as default 11 +1.<br> 4. jump step as default +1.<br>
# ### ( from backward counting, -2 is 'a' also from forward counting, 10 is 'a' ) that is why in this above code it start from -2,  it goes till 12 (point 3) but excluding 12 i.e. at 11 it get stop.

# %%
s3[10:]
# Out:
# 'as'

# %%
s3[::1]
# Out:
# 'nilutpal das'

# %% [markdown]
# ### 1. starting point as default 0.<br> 2. ending point as default 11+1.<br> 3. jump step as assigned +1.

# %%
s3[0:50:1]
# Out:
# 'nilutpal das'

# %% [markdown]
# ### you can assign any far fetched end point but it will consider it from its real end point +1.

# %%
s3[::-1]
# Out:
# 'sad laptulin'

# %% [markdown]
# ### 1. without starting point and ending point.<br> 2. starts from last index till first index.<br> 3. starting point will be last index value and end point will be first index - 1.

# %% [markdown]
# ## python way of reversing the string

# %%
string = "python"
string[::-1]
# Out:
# 'nohtyp'

# %%
s4 = "nilutpal"

# %%
s4[0:7:1]
# Out:
# 'nilutpa'

# %% [markdown]
# ### here in the above code counting starts from 0 end point is 7 but it will get excluded and get counted till 6.

# %%
s4[0:8:1]
# Out:
# 'nilutpal'

# %% [markdown]
# ### see the above result, prevoius code it gets till 'nilutpa'  but this code it gets complete 'nilutpal' by using real end point of the string i.e. 7+1.

# %% [markdown]
# ### jump of step 2

# %%
s4[0:8:2]
# Out:
# 'nlta'

# %% [markdown]
# ### for input 94, refer to input 37

# %%
s4[7:0:1]
# Out:
# ''

# %% [markdown]
# ### 1. starting point starts from 7.<br> 2. ending point is at 0. (flow is backward)<br> 3. jump with step size of 1 goes from 0 to 7. (flow is forward)<br> that is why the contradiction comes and gets no result.

# %%
s4[7:0:-1]
# Out:
# 'laptuli'

# %% [markdown]
# ### 1. starts from 7 as starting point.<br> 2. ends at 0 as ending point. (flow is backward)<br> 3. jump with step size of -1 starts from 7 to 0. (flow is backward)<br> so no contradiction and gets output in reverse as ending point -1.

# %%
s5 = "ineuron"

# %% [markdown]
# ### representation -<br> i[0][-7], n[1][-6], e[2][-5], u[3][-4], r[4][-3], o[5][-2], n[6][-1]

# %%
s5[::-1]
# Out:
# 'norueni'

# %% [markdown]
# ### from the representation,<br> 1. starting point is not mentioned, 7+1 is starting index.<br> 2. ending point is goes till last index.<br> 3. jump size of -1.

# %%
s5[-2:-7:1]
# Out:
# ''

# %% [markdown]
# ### from the representation,<br> 1. starts from -2 i.e. 'o' and ends at -7 i.e. 'i'. (flow is backward) <br> 3. jump size of 1.(flow is forward)<br> so no output.

# %%
s5[-7:-2:1]
# Out:
# 'ineur'

# %% [markdown]
# ### from representation,<br> 1. starts from -7 and ends at -2 i.e. 'o' (flow is forward)<br> 2. jump size is +1 (flow is forward)<br> so string gives output till -3 i.e. 'r' excluding -2 i.e. 'o' because string exclude the ending point.

# %% [markdown]
#  # "always while solving string slicing operation try to draw the scale of the string using lower bound(starting point) and upper bound(ending point) for better reprensenation."

# %%
s4
# Out:
# 'nilutpal'

# %%
s4[5:0]
# Out:
# ''

# %% [markdown]
# ### 1. starting point is 5 and ending point is 0. (flow is backward)<br> 2. jump size is +1 it means it goes from 0 to 5. (flow is forward)<br> each one contradicts one another, so no output.

# %%
s4[0:8:1]
# Out:
# 'nilutpal'

# %%
s4[0:7:1]
# Out:
# 'nilutpa'

# %% [markdown]
# ### representation -<br> n[0][-8], i[1][-7], l[2][-6], u[3][-5], t[4][-4], p[5][-3], a[6][-2], l[7][-1]

# %%
s4[-8:-1:1]
# Out:
# 'nilutpa'

# %%
s4[-8:0:1]
# Out:
# ''

# %%
s4[-8:0:-1]
# Out:
# ''

# %% [markdown]
# ### from both input 66 and 67, the output comes is blank.<br> reason is that both have starting and ending point same. i.e. starts from -8 and ends at 0 which are basically same.

# %%
s4[:-1:-1]
# Out:
# ''

# %% [markdown]
# ### here starting point is 0 and goes till -1.(flow is forward)<br> jump size is -1 i.e. -1 to 0 (flow is backward)

# %%
s
# Out:
# 'ineuron'

# %%
s+1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26496/3519921828.py in <module>
# ----> 1 s+1
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ### reason of error - python is a strong-typed language, it means you cannot use arithmetic operations like (add, subtract, multiply or divide) with a string datatype variable as these operations are for variable which have integer datatype.<br> both variable have to be in same datatype otherwise it will throw error.

# %% [markdown]
# ## solution

# %%
s+'1'
# Out:
# 'ineuron1'

# %%
s+"1"
# Out:
# 'ineuron1'

# %% [markdown]
# ### now both the variable are in same datatype. 's' was already a string and now by using single quote '1' is also a string.<br> for using concatenation both are in same datatype.

# %%
s+str(1)
# Out:
# 'ineuron1'

# %% [markdown]
# ### you can use typecasting for this case, as typecasting can also help in concatenation

# %%
"nilutpal" + 1234567890
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26496/4192620069.py in <module>
# ----> 1 "nilutpal" + 1234567890
#
# TypeError: can only concatenate str (not "int") to str

# %%
"nilutpal" + "1234567890"
# Out:
# 'nilutpal1234567890'

# %% [markdown]
# ### len() function

# %%
s
# Out:
# 'ineuron'

# %%
len(s)
# Out:
# 7

# %% [markdown]
# ### len function return the length of the string

# %%
s
# Out:
# 'ineuron'

# %% [markdown]
# ### string multiplication operation

# %%
s * 5
# Out:
# 'ineuronineuronineuronineuronineuron'

# %% [markdown]
# ### return string gets multiplied the number of times,<br> you have mentioned along with the string.

# %% [markdown]
# ### you can check all the in-built function for string,<br> first type the string and '.' then click "tab". you'll get the list.
#
# ### you can get the idea of any function, first type the function, use normal bracket and inside the bracket click "shift + tab".

# %%
a = 'ineuronineuronineuronineuronineuron'

# %% [markdown]
# ### count() function

# %%
a.count('n')
# Out:
# 10

# %% [markdown]
# ### count return how many times the letter 'n' is being used in the string 'a'.

# %%
a.count('in')
# Out:
# 5

# %% [markdown]
# ### split() function

# %%
 a
# Out:
# 'ineuronineuronineuronineuronineuron'

# %%
a.split('n')
# Out:
# ['i', 'euro', 'i', 'euro', 'i', 'euro', 'i', 'euro', 'i', 'euro', '']

# %% [markdown]
# ### Return a list of the words in the string, using sep as the delimiter string which split the string.<br> whatever letter you mentioned inside the bracket as sep. that will split the string by checking letter available before, in between and after the string.

# %% [markdown]
# ### here in the above example, the string 'ineuronineuronineuronineuronineuron' get splitted using seperator as 'n'. means it split the string whenever there comes the word 'n' and enclosed them into list.

# %%
sam = """Samsung Group,[3] or simply Samsung (Korean: 삼성; RR: samseong [samsʌŋ]) (stylized as SΛMSUNG), is a South Korean multinational manufacturing conglomerate headquartered in Samsung Town, Seoul, South Korea.[1]"""

# %% [markdown]
# ### in the above code, you can see that using the triple quote we have enclosed entire string.while working with multiline paragraph use triple quote.

# %%
sam
# Out:
# 'Samsung Group,[3] or simply Samsung (Korean: 삼성; RR: samseong [samsʌŋ]) (stylized as SΛMSUNG), is a South Korean multinational manufacturing conglomerate headquartered in Samsung Town, Seoul, South Korea.[1]'

# %%
sam1 = sam.split(" ")
sam1
# Out:
# ['Samsung',
#  'Group,[3]',
#  'or',
#  'simply',
#  'Samsung',
#  '(Korean:',
#  '삼성;',
#  'RR:',
#  'samseong',
#  '[samsʌŋ])',
#  '(stylized',
#  'as',
#  'SΛMSUNG),',
#  'is',
#  'a',
#  'South',
#  'Korean',
#  'multinational',
#  'manufacturing',
#  'conglomerate',
#  'headquartered',
#  'in',
#  'Samsung',
#  'Town,',
#  'Seoul,',
#  'South',
#  'Korea.[1]']

# %% [markdown]
# ### here it splits the string by using seperator as a space " ".

# %%
sam1.count('Samsung')
# Out:
# 3

# %% [markdown]
# ### counts how many times the word Samsung comes in the string sam1.

# %% [markdown]
# ### upper() function

# %%
sam.upper()
# Out:
# 'SAMSUNG GROUP,[3] OR SIMPLY SAMSUNG (KOREAN: 삼성; RR: SAMSEONG [SAMSɅŊ]) (STYLIZED AS SΛMSUNG), IS A SOUTH KOREAN MULTINATIONAL MANUFACTURING CONGLOMERATE HEADQUARTERED IN SAMSUNG TOWN, SEOUL, SOUTH KOREA.[1]'

# %% [markdown]
# ### in the above code, it returns whole string into uppercase.

# %% [markdown]
# ### lower() function

# %%
sam.lower()
# Out:
# 'samsung group,[3] or simply samsung (korean: 삼성; rr: samseong [samsʌŋ]) (stylized as sλmsung), is a south korean multinational manufacturing conglomerate headquartered in samsung town, seoul, south korea.[1]'

# %% [markdown]
# ### in the above code, it returns whole string into lowercase.

# %% [markdown]
# ### title() function

# %%
s = 'ineuron intelligence'
s
# Out:
# 'ineuron intelligence'

# %%
s.title()
# Out:
# 'Ineuron Intelligence'

# %% [markdown]
# ### it makes the first word of every string in uppercase.

# %% [markdown]
# ### capitalize() function

# %%
s.capitalize()
# Out:
# 'Ineuron intelligence'

# %% [markdown]
# ### it makes only the first word of first string in uppercase rest lowercase.

# %%
s3 = 'NilutpaL daS'
s3
# Out:
# 'NilutpaL daS'

# %% [markdown]
# ### swapcase() function

# %%
s3.swapcase()
# Out:
# 'nILUTPAl DAs'

# %% [markdown]
# ### convert uppercase characters to lowercase and lowercase characters to uppercase.

# %% [markdown]
# ### reversed() function

# %%
reversed(s3)

# %%
''.join(reversed(s3))
# Out:
# 'Sad LaptuliN'

# %% [markdown]
# ### return a reverse iterator over the values of the given sequence.

# %%
s4 = "    nilutpal    "
s4
# Out:
# '    nilutpal    '

# %% [markdown]
# ### strip() function

# %%
s4
# Out:
# '    nilutpal    '

# %%
s4.strip()
# Out:
# 'nilutpal'

# %% [markdown]
# ### removes spaces from before and after of a string but not in betweeen.

# %%
s4
# Out:
# '    nilutpal    '

# %% [markdown]
# ### lstrip() function

# %%
s4.lstrip()
# Out:
# 'nilutpal    '

# %% [markdown]
# ### removes spaces from left hand side.

# %% [markdown]
# ### rstrip() function

# %%
s4.rstrip()
# Out:
# '    nilutpal'

# %% [markdown]
# ### removes spaces from right hand side.

# %%
" ".join("nilutpal")
# Out:
# 'n i l u t p a l'

# %% [markdown]
# ### it adds the character between your string.

# %% [markdown]
# ### center() function - this reserves the width in left and right side of the string and adds the stack of mentioned character so that the string comes in the center.

# %%
s5
# Out:
# 'ineuron'

# %%
s5.center(30, "s")
# Out:
# 'sssssssssssineuronssssssssssss'

# %% [markdown]
# ### function starting with "is" used to check the string is true or false.

# %% [markdown]
# ### isalnum() - this check whether the string is alphabet or numeric

# %%
s5.isalnum()
# Out:
# True

# %% [markdown]
# ### isupper() - this check whether isupper is uppercase or not.<br> answer is false it is not.

# %%
s5.isupper()
# Out:
# False

# %%
s6 = "NILUTPAL"

# %%
s6.isupper()
# Out:
# True

# %% [markdown]
# ### islower() - check whether string is lowercase or not

# %%
s6.islower()
# Out:
# False

# %% [markdown]
# ### isspace() - check whether there is a space or not

# %%
s4.isspace()
# Out:
# False

# %%
s3
# Out:
# 'NilutpaL daS'

# %%
s3.islower()
# Out:
# False

# %%
a
# Out:
# 'ineuronineuronineuronineuronineuron'

# %%
b = '123456'

# %% [markdown]
# ### isnumeric()

# %%
b.isnumeric()
# Out:
# True

# %% [markdown]
# ### isdigit() - check whether string contains digit or not

# %%
b.isdigit()
# Out:
# True

# %%
s6
# Out:
# 'NILUTPAL'

# %%
s7 = "12345nildas"

# %% [markdown]
# ### isalnum() - check whether string contains of alphabet and numeric

# %%
s7.isalnum()
# Out:
# True

# %%
s7.isnumeric()
# Out:
# False

# %%
s7.isdigit()
# Out:
# False

# %% [markdown]
# ### startswith() - return the character which is in the first place

# %%
s7.startswith('1')
# Out:
# True

# %%
s
# Out:
# 'ineuron intelligence'

# %%
s.startswith("i")
# Out:
# True

# %% [markdown]
# ### endswith() - returns the character which is in the last place

# %%
s.endswith('e')
# Out:
# True

# %%
s7
# Out:
# '12345nildas'

# %% [markdown]
# ### isdigit() - check the string is all digits or not.

# %%
s7.isdigit()
# Out:
# False

# %%
s8 = "12345a"

# %% [markdown]
# ### isunumeric() - check whether string contains alphabet + numeric or not.

# %%
s8.isnumeric()
# Out:
# False

# %% [markdown]
# ### expandtabs()

# %%
s = "nilutpal\tdas"

# %%
s.expandtabs()
# Out:
# 'nilutpal        das'

# %% [markdown]
# # task

# %%
s = "this is My First Python programming class and i am learNING python string and its function"
1 . Try to extract data from index one to index 300 with a jump of 3 
2. Try to reverse a string without using reverse function 
3. Try to split a string after conversion of entire string in uppercase 
4. try to convert the whole string into lower case 
5 . Try to capitalize the whole string 
6 . Write a diference between isalnum() and isalpha()
7. Try to give an example of expand tab
8 . Give an example of strip , lstrip and rstrip 
9.  Replace a string charecter by another charector by taking your own example 
10 . Try  to give a defination of string center function with and exmple 
11 . Write your own definition of compiler and interpretor without copy paste form internet in your own language
12 . Python is a interpreted of compiled language give a clear ans with your understanding 
13 . Try to write a usecase of python with your understanding .

# %%
s = "this is my first python programming class and i am learning python string and its function"

# %%
#1 . Try to extract data from index one to index 300 with a jump of 3 
s[1:300:3]
# Out:
# 'h   r tnrrmglsnimengyosi dtfco'

# %%
#2. Try to reverse a string without using reverse function 
s[::-1]
# Out:
# 'noitcnuf sti dna gnirts nohtyp gninrael ma i dna ssalc gnimmargorp nohtyp tsrif ym si siht'

# %%
#3. Try to split a string after conversion of entire string in uppercase
s1 = s.upper()
s1.split(" ")
# Out:
# ['THIS',
#  'IS',
#  'MY',
#  'FIRST',
#  'PYTHON',
#  'PROGRAMMING',
#  'CLASS',
#  'AND',
#  'I',
#  'AM',
#  'LEARNING',
#  'PYTHON',
#  'STRING',
#  'AND',
#  'ITS',
#  'FUNCTION']

# %%
#4. try to convert the whole string into lower case
s.lower()
# Out:
# 'this is my first python programming class and i am learning python string and its function'

# %%
#5 . Try to capitalize the whole string
s.capitalize()
# Out:
# 'This is my first python programming class and i am learning python string and its function'

# %% [markdown]
# ### difference between isalpha and isalnum

# %%
#6 . Write a diference between isalnum() and isalpha()
print("isalpha check whether there is an alphabet or not")
# Out:
# isalpha check whether there is an alphabet or not

# %%
print("isalnum check whether there is alphabet and numeric or not")
# Out:
# isalnum check whether there is alphabet and numeric or not

# %%
#7. Try to give an example of expand tab
s2 = "nilutpal\tdas"
s2.expandtabs()
# Out:
# 'nilutpal        das'

# %%
#8 . Give an example of strip , lstrip and rstrip 
s3 = "     nildas     "

# %%
s3.lstrip()
# Out:
# 'nildas     '

# %%
s3.rstrip()
# Out:
# '     nildas'

# %%
s3.strip()
# Out:
# 'nildas'

# %%
#9.  Replace a string charecter by another charector by taking your own example 
s4 = "nil-das"
s4.replace("-", " ")
# Out:
# 'nil das'

# %%
#10 . Try  to give a defination of string center function with and exmple 
s5 = "nildas"
s5.center(10, "z")
# Out:
# 'zznildaszz'
